# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

import json

#class_info = json.load(open("video_data.json"))

#print(class_info)

fig = plt.figure(figsize=(15, 15))
m = Basemap(projection='merc',llcrnrlat=36.560581,urcrnrlat=38.558705,\
            llcrnrlon=-123.146212,urcrnrlon=-122.227296,lat_ts=20,resolution='f')
m.drawcoastlines()
m.fillcontinents(color='coral',lake_color='aqua')
# draw parallels and meridians.
m.drawparallels(np.arange(-90.,91.,30.))
m.drawmeridians(np.arange(-180.,181.,60.))
m.drawmapboundary(fill_color='aqua')
plt.title("Mercator Projection")
# Out:
# Text(0.5, 1.0, 'Mercator Projection')

# %%
class_info = json.load(open("video_data.json"))

lv2 = {}
for i in range(8):
    lv2[i] = []

for key in class_info:
    if class_info[key]
# Out:
# {0: [], 1: [], 2: [], 3: [], 4: [], 5: [], 6: [], 7: []}
